# %% [markdown]
# # bash

# %%
bart version
# Out:
# v0.4.04

# %%
sh figure2a.sh
# Out:
# Done.

# %%
bart reshape $(bart bitmask 1 2 4) 192 $((192 * 8)) 1 figure2a tmp
imshow tmp

# %%
sh figure2b.sh
# Out:
# Done.
# Calibration region 1x20x20
# Done.

# %%
bart slice 4 0 figure2b tmp
bart reshape $(bart bitmask 1 2 3) 192 $((192 * 8)) 1 tmp tmp2
imshow tmp2

# %%
bart extract 4 2 4 figure2b tmp
bart transpose 4 0 tmp tmp2
bart transpose 0 1 tmp2 tmp
bart reshape $(bart bitmask 0 1 2 3) 1 $((2 * 192)) $((192 * 8)) 1 tmp tmp2
imshow tmp2

# %%
bart slice 4 1 figure2b tmp
bart reshape $(bart bitmask 1 2 3) 192 $((192 * 8)) 1 tmp tmp2
imshow tmp2

# %%
sh figure4a.sh
# Out:
# Calibration region 1x24x24
# Done.
# Done.
# Calibration region 1x20x20
# Done.
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 26.792293
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 26.386197
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization of imaginary part: 0.001000
# ADMM
# Total Time: 30.986767
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization of imaginary part: 0.001000
# ADMM
# Total Time: 29.580846
# 2 maps.
# ESPIRiT reconstruction.
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 38.291837

# %%
imshow figure4a

# %%
sh figure4b.sh
# Out:
# Calibration region 1x24x24
# Done.
# Done.
# Calibration region 1x20x20
# Done.
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 23.240987
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 24.883939
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization of imaginary part: 0.001000
# ADMM
# Total Time: 31.880735
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 26.887929
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization of imaginary part: 0.001000
# ADMM
# Total Time: 32.200596
# 2 maps.
# ESPIRiT reconstruction.
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 40.587088

# %%
imshow figure4b

# %%
sh figure5.sh
# Out:
# Done.
# Calibration region 1x20x20
# Done.
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 21.296881
# 2 maps.
# ESPIRiT reconstruction.
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 23.994628
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization of imaginary part: 0.001000
# ADMM
# Total Time: 16.786827

# %%
imshow figure5
