# %% [markdown]
# # VCC-ESPIRiT using BART

# %%
bart version
# Out:
# v0.5.00

# %%
sh figure2a.sh
# Out:
# Done.

# %%
bart reshape $(bart bitmask 1 2 4) 192 $((192 * 8)) 1 figure2a tmp
imshow tmp

# %%
sh figure2b.sh
# Out:
# Done.
# Calibration region 1x20x20
# Done.

# %%
bart slice 4 0 figure2b tmp
bart reshape $(bart bitmask 1 2 3) 192 $((192 * 8)) 1 tmp tmp2
imshow tmp2

# %%
bart extract 4 2 4 figure2b tmp
bart transpose 4 0 tmp tmp2
bart transpose 0 1 tmp2 tmp
bart reshape $(bart bitmask 0 1 2 3) 1 $((2 * 192)) $((192 * 8)) 1 tmp tmp2
imshow tmp2

# %%
bart slice 4 1 figure2b tmp
bart reshape $(bart bitmask 1 2 3) 192 $((192 * 8)) 1 tmp tmp2
imshow tmp2

# %%
# we skip figure 3 because it takes to long to compute...
# sh figure3.sh

# %%
sh figure4a.sh
# Out:
# Calibration region 1x24x24
# Done.
# Done.
# Calibration region 1x20x20
# Done.
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 19.906249
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 19.566400
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization of imaginary part: 0.001000
# ADMM
# Total Time: 26.367795
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization of imaginary part: 0.001000
# ADMM
# Total Time: 25.568713
# 2 maps.
# ESPIRiT reconstruction.
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 29.466071

# %%
imshow figure4a

# %%
sh figure4b.sh
# Out:
# Calibration region 1x24x24
# Done.
# Done.
# Calibration region 1x20x20
# Done.
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 21.446107
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 21.877163
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization of imaginary part: 0.001000
# ADMM
# Total Time: 22.745671
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 21.965419
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization of imaginary part: 0.001000
# ADMM
# Total Time: 23.165875
# 2 maps.
# ESPIRiT reconstruction.
# Size: 36864 Samples: 6635 Acc: 5.56
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 24.458590

# %%
imshow figure4b

# %%
sh figure5.sh
# Out:
# Done.
# Calibration region 1x20x20
# Done.
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 23.081520
# 2 maps.
# ESPIRiT reconstruction.
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization: 0.001000
# conjugate gradients
# Total Time: 32.177661
# Size: 36864 Samples: 12679 Acc: 2.91
# l2 regularization of imaginary part: 0.001000
# ADMM
# Total Time: 24.716567

# %%
imshow figure5
